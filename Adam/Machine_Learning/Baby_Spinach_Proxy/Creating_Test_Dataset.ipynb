# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Move to Dataset directory

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset

# %%
ls
# Out:
#  Healthy/  'Yellow Leaf Curl'/

# %% [markdown]
# Directories for Healthy and Yellow Leaf Curl

# %%
healthy_directory = "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Healthy"

# %%
yellow_curl = "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Yellow Leaf Curl"

# %% [markdown]
# Shuffle 20% and move to test directory for both datasets

# %%
# !find ./Healthy -type f -name "*.JPG" | awk '!/Yellow Leaf Curl/' | shuf -n 319 | xargs -I X -t mv X Test/Healthy/

# %%
# !find './Yellow Leaf Curl' -type f -name "*.JPG" | awk '!/Healthy/' | shuf -n 642 | xargs -I X -t mv X 'Test/Yellow Leaf Curl/'
# Out:
# mv ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2014.JPG Test/Yellow Leaf Curl/
# mv ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2449.JPG Test/Yellow Leaf Curl/
# mv ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2735.JPG Test/Yellow Leaf Curl/
# mv ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2520.JPG Test/Yellow Leaf Curl/
# mv ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_1198.JPG Test/Yellow Leaf Curl/
# mv ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_1896.JPG Test/Yellow Leaf Curl/
# mv ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_1824.JPG Test/Yellow Leaf Curl/
# mv ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2295.JPG Test/Yellow Leaf Curl/
# mv ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_0856.JPG Test/Yellow Leaf Curl/
# mv ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_1230.JPG Test/Yellow Leaf Curl/
# mv ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2889.JPG Test/Yellow Leaf Curl/
# mv ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_0073.JPG Test/Yellow Leaf Curl/
# ...

# %% [markdown]
# Count Healthy Image Set

# %%
cd '/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Test/Healthy'
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Test/Healthy

# %%
ls | wc -l
# Out:
# 319

# %% [markdown]
# Count Yellow Leaf Curl Image Set

# %%
cd '/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Test/Yellow Leaf Curl'
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Test/Yellow Leaf Curl

# %%
ls | wc -l
# Out:
# 642

# %% [markdown]
# Count Healthy Image Set for Train Folder

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Healthy"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Healthy

# %%
ls | wc -l
# Out:
# 1272

# %% [markdown]
# Count Yellow Leaf Curl Image Set for Train Folder

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Yellow Leaf Curl"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Yellow Leaf Curl

# %%
ls | wc -l
# Out:
# 2566

# %% [markdown]
# Create Train Folder Dataset

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset

# %%
# !find './Healthy' -type f -name "*.JPG" | awk '!/Yellow Leaf Curl/' | xargs -I X -t cp X './Train'
# Out:
# cp ./Healthy/Tomato_Healthy_0580.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0569.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0050.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0402.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0206.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0051.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0056.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0295.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0179.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0082.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0524.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0340.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0121.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0247.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0369.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0534.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0622.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0492.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0415.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0104.JPG ./Train
# cp ./Healthy/Tomato_Healthy_0007.JPG ./Train
# ...

# %%
# !find './Yellow Leaf Curl' -type f -name "*.JPG" | awk '!/Healthy/' | xargs -I X -t cp X './Train'
# Out:
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2998.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2283.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2458.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2778.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2567.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2148.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_3125.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2069.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2343.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2798.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2242.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2822.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2821.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2357.JPG ./Train
# cp ./Yellow Leaf Curl/Tomato_Yellow_Leaf_Curl_2628.JPG ./Train
# ...

# %% [markdown]
# Count Total Images in Train Set

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Train"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Train

# %%
ls | wc -l
# Out:
# 3837

# %%
# !find ./Healthy -type f -name "*.JPG" | awk '!/Yellow Leaf Curl/' | shuf -n 319 | xargs -I X -t mv X Test/Healthy/
