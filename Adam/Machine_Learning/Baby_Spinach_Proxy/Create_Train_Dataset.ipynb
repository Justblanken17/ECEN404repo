# %%
import os
import numpy as np
import pandas as pd
import shutil

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Gaussian_Noise_Augmentation/Healthy"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Gaussian_Noise_Augmentation/Healthy

# %%
ls | wc -l
# Out:
# 1271

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Gaussian_Noise_Augmentation/Yellow Leaf Curl"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Gaussian_Noise_Augmentation/Yellow Leaf Curl

# %%
ls | wc -l
# Out:
# 2566

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Vertical_Flip_Augmentation/Healthy"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Vertical_Flip_Augmentation/Healthy

# %%
ls | wc -l
# Out:
# 1271

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Vertical_Flip_Augmentation/Yellow Leaf Curl"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Vertical_Flip_Augmentation/Yellow Leaf Curl

# %%
ls | wc -l
# Out:
# 2566

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Shearing_Augmentation/Healthy"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Shearing_Augmentation/Healthy

# %%
ls | wc -l
# Out:
# 1271

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Shearing_Augmentation/Yellow Leaf Curl"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Shearing_Augmentation/Yellow Leaf Curl

# %%
ls | wc -l
# Out:
# 2566

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Original_Dataset/Healthy"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Original_Dataset/Healthy

# %%
ls | wc -l
# Out:
# 1271

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Original_Dataset/Yellow Leaf Curl"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Original_Dataset/Yellow Leaf Curl

# %%
ls | wc -l
# Out:
# 2566

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Gaussian_Blur/Healthy"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Gaussian_Blur/Healthy

# %%
ls | wc -l
# Out:
# 1271

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Gaussian_Blur/Yellow Leaf Curl"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Gaussian_Blur/Yellow Leaf Curl

# %%
ls | wc -l
# Out:
# 2566

# %% [markdown]
# Total Size of Dataset = 19185

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Gaussian_Blur"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset/Gaussian_Blur

# %%
ls
# Out:
#  Healthy/  'Yellow Leaf Curl'/

# %%
# !find './Yellow Leaf Curl' -type f -name "*.JPG" | awk '!/Healthy/' | xargs -I X -t cp X '/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Train'
# Out:
# cp ./Yellow Leaf Curl/Gaussian_Blur_Tomato_Yellow_Leaf_Curl_0744.JPG /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Train
# cp ./Yellow Leaf Curl/Gaussian_Blur_Tomato_Yellow_Leaf_Curl_0658.JPG /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Train
# cp ./Yellow Leaf Curl/Gaussian_Blur_Tomato_Yellow_Leaf_Curl_1218.JPG /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Train
# cp ./Yellow Leaf Curl/Gaussian_Blur_Tomato_Yellow_Leaf_Curl_1205.JPG /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Train
# cp ./Yellow Leaf Curl/Gaussian_Blur_Tomato_Yellow_Leaf_Curl_1643.JPG /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Train
# cp ./Yellow Leaf Curl/Gaussian_Blur_Tomato_Yellow_Leaf_Curl_1087.JPG /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Train
# ...

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Train"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Train

# %%
count = 0
for root, dirs, files in os.walk('/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Train'):
  for name in files:
    count += 1

print(count)
# Out:
# 15446

# %%
ls | wc -l
# Out:
# ls: cannot open directory '.': Input/output error
# 0

# %%
cd "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/"
# Out:
# /content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model

# %%
train_directory = "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Dataset"
classes = ["Healthy", "Yellow Leaf Curl"]

# %%
target = "/content/drive/Shareddrives/ECEN 404 Machine Learning/Color/Final Model/Temp_Train"

# %%
for i in os.listdir(train_directory):
  for j in classes:
    path = os.path.join(train_directory, i, j)
    class_num = classes.index(j)
    for img in os.listdir(path):
      shutil.copy2(os.path.join(path, img), target)
